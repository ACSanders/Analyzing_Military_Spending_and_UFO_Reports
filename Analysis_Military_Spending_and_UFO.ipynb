# %% [markdown]
# # Analyzing Military Spending and UFO Reports
# ### A Data Analysis Project (Work in Progress)

# %% [markdown]
# ## Author
# ### Adam C. Sanders

# %% [markdown]
# ## Introduction
# It is a fact that UFOs (i.e., unidentified flying objects) have become a topic of interest for many people. At first glance, this interest seems to have grown over the years. There are now numerous television shows, movies, and video games that focus on UFOs. UFOs have also been discussed and debated on news outlets and social media sites.
#
# There are several interesting questions we can explore. Of course, there are epistemic questions regarding the justification and rationality of belief in UFOs. If an agent, S, at time, t1, believes to have seen a UFO, then is S's belief at t1 rational? This is a contextual question that depends on S's justification at t1. There are also questions regarding the nature of UFOs. For instance, are instances of UFO sightings (1) cases of mistaken identity or (2) cases involving extraterestrial space crafts. As for (1), these cases can break down into several other categories. One might, for example, mistake the occurrence of some natural phenomena as a UFO (e.g., a unique weather pattern). In other cases, one might mistake exotic aircraft as being UFOs (e.g., experimental military aircraft of terestrial origins).
#
# For the purpose of this project, I will not focus on matters of epistemic justification for a given agent's belief in UFOs. I take it for granted that a belief or degree of belief is justified insofar as the target propostion is sufficiently justified. I will also avoid focusing on the accuracy of UFO sightings. Instead, I will investigate whether there are interesting relationships that hold between U. S. military spending and the frequency of UFO reports between 2004 and 2013. One might think that when there is an increase in military spending, there is an increase in the development and application of new military technology. This new technology would also include the development of new aircraft. So, it might be the case that an increase in new military technology could lead to an increase in unexplained sightings that can subsequently be reported as UFOs. This is the issue that I will address.

# %% [markdown]
# ## Questions
# I will investigate several questions:
# #### (1) Has there been an increase in UFO reports in the United States between 2004 and 2013?
# #### (2) Has there been an increase in military spending in the United States between 2004 and 2013?
# #### (3) Is there any correlation between the frequency of UFO reports and military spending?

# %% [markdown]
# ## Hypothesis
#
# #### (1) There is a positive correlation between military spending and UFO reports in the United States. As U. S. military spending increases, the frequency of UFO reports increases.

# %% [markdown]
# ## Methodology and Tools
# #### Languages and Libraries
# I will use Python to analyze and visualize information from several datasets. The specific libraries I will use include Pandas, Matplotlib, Numpy, and Seaborn.
# #### Data
# I will pull information from several datasets on Kaggle. These datasets cover military spending by country, world happiness scores, and UFO reports. The acknowledgement section provides further information.
# #### Analysis
# I will perform some basic data visualization and exploratory analysis on two select datasets. I will also test for correlation between select variables.

# %% [markdown]
# ## Acknowledgements
# #### Military Spending of Countries dataset
# STOCKHOLM INTERNATIONAL PEACE RESEARCH INSTITUTE (SIPRI) and
# The World Bank Database.
# Accessed from Kaggle https://www.kaggle.com/nitinsss/military-expenditure-of-countries-19602019
# #### UFO Sightings
# National UFO Reporting Center (NUFORC)
# https://github.com/planetsig/ufo-reports.
# Accessed from Kaggle https://www.kaggle.com/NUFORC/ufo-sightings

# %% [markdown]
# ## Caveats
# For my purpose, I take several propositions for granted. First, it is assumed that there has been an increase in interest in UFOs. This assumption is based on the apparent increase in the number of television shows and movies that have focused on UFO activities. Second, it is assumed that the number of UFO reports referenced in the data does not represent the total number of UFO sightings. Many UFO sightings are never reported, and therefore the total number of UFO sightings is expected to be higher than the number of UFO reports. In addition to these assumptions, it is important to keep in mind that this project is being continuously developed over time and is not in a finished state.

# %% [markdown]
# # Table of Contents
# ### Part 1: Importing LIbraries and Data
# ### Part 2: Exploring Military Spending in the U. S.
# ### Part 3: Preliminary Analysis of U. S. Spending
# ### Part 4: Exploring UFO Reports in the U. S.
# ### Part 5: Preliminary Analysis of UFO Reports
# ### Part 6: The Relationship Between U. S. Military Spending and UFO Reports
# ### Part 7: Discussion

# %% [markdown]
# # Part 1: Importing Libraries and Data

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import military spending dataset
military = pd.read_csv("C:/Users/Sande/Desktop/Datasets/MilitaryExpenditure.csv")

# %%
# data check of military spending by displaying the first 5 rows
military.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08  3.258070e+08
# 2   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09  3.639496e+09
# 3   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08  1.970068e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
#            2012          2013          2014          2015          2016  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.385834e+08  2.171941e+08  2.682271e+08  1.995186e+08  1.858783e+08
# 2  4.144635e+09  6.090752e+09  6.841864e+09  3.608299e+09  2.764055e+09
# 3  1.832047e+08  1.800155e+08  1.781204e+08  1.323507e+08  1.308532e+08
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2017          2018
# 0           NaN           NaN
# 1  1.914071e+08  1.980863e+08
# 2  3.062873e+09  1.983614e+09
# 3  1.443827e+08  1.804887e+08
# 4           NaN           NaN
#
# [5 rows x 63 columns]

# %%
# import UFO dataset
ufodf = pd.read_csv("C:/Users/Sande/Desktop/Datasets/UFOSightings.csv")

# %%
# data check of UFO reports by displaying first 5 rows
ufodf.head()
# Out:
#      datetime                  city state country     shape  \
# 0  10/10/1949            san marcos    tx      us  cylinder
# 1  10/10/1949          lackland afb    tx     NaN     light
# 2  10/10/1955  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956                  edna    tx      us    circle
# 4  10/10/1960               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#     longitude  Unnamed: 11
# 0  -97.941111          NaN
# 1  -98.581082          NaN
# 2   -2.916667          NaN
# 3  -96.645833          NaN
# 4 -157.803611          NaN

# %% [markdown]
# # Part 2: Exploring Military Spending in the U. S.
# In this section I will slice the military spending data to obtain a dataframe that consists of only U. S. military spending data from 2004 to 2013. I will then perform exploratory data analysis.

# %%
# Create a subset of data that includes only U. S. spending

us_military = military[military["Name"] == "United States"]
us_military.head()
# Out:
#               Name Code     Type                      Indicator Name  \
# 249  United States  USA  Country  Military expenditure (current USD)
#
#                   1960               1961               1962  \
# 249 45380000000.000000 47808000000.000000 52381000000.000000
#
#                   1963               1964               1965  ...  \
# 249 52295000000.000000 51213000000.000000 51827000000.000000  ...
#
#                    2009                2010                2011  \
# 249 669000000000.000000 698000000000.000000 711000000000.000000
#
#                    2012                2013                2014  \
# 249 685000000000.000000 640000000000.000000 610000000000.000000
#
#                    2015                2016                2017  \
# 249 596000000000.000000 600000000000.000000 606000000000.000000
#
#                    2018
# 249 649000000000.000000
#
# [1 rows x 63 columns]

# %%
# Summary statistics of U. S. military spending from 1960 to 2018
us_military.describe()
# Out:
#                     1960               1961               1962  \
# count           1.000000           1.000000           1.000000
# mean  45380000000.000000 47808000000.000000 52381000000.000000
# std                  nan                nan                nan
# min   45380000000.000000 47808000000.000000 52381000000.000000
# 25%   45380000000.000000 47808000000.000000 52381000000.000000
# 50%   45380000000.000000 47808000000.000000 52381000000.000000
# 75%   45380000000.000000 47808000000.000000 52381000000.000000
# max   45380000000.000000 47808000000.000000 52381000000.000000
#
#                     1963               1964               1965  \
# count           1.000000           1.000000           1.000000
# mean  52295000000.000000 51213000000.000000 51827000000.000000
# std                  nan                nan                nan
# min   52295000000.000000 51213000000.000000 51827000000.000000
# 25%   52295000000.000000 51213000000.000000 51827000000.000000
# 50%   52295000000.000000 51213000000.000000 51827000000.000000
# 75%   52295000000.000000 51213000000.000000 51827000000.000000
# max   52295000000.000000 51213000000.000000 51827000000.000000
#
#                     1966               1967               1968  \
# count           1.000000           1.000000           1.000000
# mean  63572000000.000000 75448000000.000000 80732000000.000000
# std                  nan                nan                nan
# min   63572000000.000000 75448000000.000000 80732000000.000000
# 25%   63572000000.000000 75448000000.000000 80732000000.000000
# 50%   63572000000.000000 75448000000.000000 80732000000.000000
# 75%   63572000000.000000 75448000000.000000 80732000000.000000
# max   63572000000.000000 75448000000.000000 80732000000.000000
#
#                     1969  ...                2009                2010  \
# count           1.000000  ...            1.000000            1.000000
# mean  81443000000.000000  ... 669000000000.000000 698000000000.000000
# std                  nan  ...                 nan                 nan
# min   81443000000.000000  ... 669000000000.000000 698000000000.000000
# 25%   81443000000.000000  ... 669000000000.000000 698000000000.000000
# 50%   81443000000.000000  ... 669000000000.000000 698000000000.000000
# 75%   81443000000.000000  ... 669000000000.000000 698000000000.000000
# max   81443000000.000000  ... 669000000000.000000 698000000000.000000
#
#                      2011                2012                2013  \
# count            1.000000            1.000000            1.000000
# mean  711000000000.000000 685000000000.000000 640000000000.000000
# std                   nan                 nan                 nan
# min   711000000000.000000 685000000000.000000 640000000000.000000
# 25%   711000000000.000000 685000000000.000000 640000000000.000000
# 50%   711000000000.000000 685000000000.000000 640000000000.000000
# 75%   711000000000.000000 685000000000.000000 640000000000.000000
# max   711000000000.000000 685000000000.000000 640000000000.000000
#
#                      2014                2015                2016  \
# count            1.000000            1.000000            1.000000
# mean  610000000000.000000 596000000000.000000 600000000000.000000
# std                   nan                 nan                 nan
# min   610000000000.000000 596000000000.000000 600000000000.000000
# 25%   610000000000.000000 596000000000.000000 600000000000.000000
# 50%   610000000000.000000 596000000000.000000 600000000000.000000
# 75%   610000000000.000000 596000000000.000000 600000000000.000000
# max   610000000000.000000 596000000000.000000 600000000000.000000
#
#                      2017                2018
# count            1.000000            1.000000
# mean  606000000000.000000 649000000000.000000
# std                   nan                 nan
# min   606000000000.000000 649000000000.000000
# 25%   606000000000.000000 649000000000.000000
# 50%   606000000000.000000 649000000000.000000
# 75%   606000000000.000000 649000000000.000000
# max   606000000000.000000 649000000000.000000
#
# [8 rows x 59 columns]

# %%
# Create a dataframe that contains data of U. S. military spending between 2004 and 2013
us_military_df = us_military[["2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013"]]
print(us_military_df)
# Out:
#                    2004                2005                2006  \
# 249 465000000000.000000 503000000000.000000 528000000000.000000
#
#                    2007                2008                2009  \
# 249 557000000000.000000 621000000000.000000 669000000000.000000
#
#                    2010                2011                2012  \
# 249 698000000000.000000 711000000000.000000 685000000000.000000
#
#                    2013
# 249 640000000000.000000

# %%
# Transpose the dates to rows.
us_military_df = us_military_df.T
us_military_df
# Out:
#                      249
# 2004 465000000000.000000
# 2005 503000000000.000000
# 2006 528000000000.000000
# 2007 557000000000.000000
# 2008 621000000000.000000
# 2009 669000000000.000000
# 2010 698000000000.000000
# 2011 711000000000.000000
# 2012 685000000000.000000
# 2013 640000000000.000000

# %%
# Remove the old country ID and attach a new column name
us_military_df.rename(columns = {249: "US Spending"}, inplace = True)
us_military_df
# Out:
#              US Spending
# 2004 465000000000.000000
# 2005 503000000000.000000
# 2006 528000000000.000000
# 2007 557000000000.000000
# 2008 621000000000.000000
# 2009 669000000000.000000
# 2010 698000000000.000000
# 2011 711000000000.000000
# 2012 685000000000.000000
# 2013 640000000000.000000

# %% [markdown]
# # Part 3: Preliminary Analysis of U. S. Spending
# ### Sum, Average, Min, Max, and Visualizing the Data

# %%
# The sum of U. S. military spending between 2004 and 2013
military_total = us_military_df["US Spending"].sum()
print(military_total)
# Out:
# 6077000000000.0

# %%
# The average amount of military spending
military_avg = military_total / 10
print(military_avg)
# Out:
# 607700000000.0

# %%
# The minimum amount of U. S. spending
us_minimum = us_military_df["US Spending"].min()
print(us_minimum)
# Out:
# 465000000000.0

# %%
# The maximum amount of U. S. spending
us_maximum = us_military_df["US Spending"].max()
print(us_maximum)
# Out:
# 711000000000.0

# %%
# Visualizing U. S. military spending between 2004 and 2013
spending_list = us_military_df["US Spending"]
years = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
plt.plot(years, spending_list)
plt.xlabel("Years")
plt.ylabel("U. S. Military Spending")
plt.title("U. S. Military Spending Between 2004 and 2013")
plt.show()

# %% [markdown]
# # Part 4: Exploring UFO Reports in the U. S
# In this part I will create a dataframe of the number of UFO reports between 2004 and 2013.

# %%
# Prepare the datetime column.

ufodf["datetime"] = pd.to_datetime(ufodf.datetime)

# %%
# Creating a dataframe of UFO reports in 2004, and then checking the data by displaying the first 5 rows.
ufo2004 = ufodf.loc[(ufodf.datetime >= "1/1/2004") & (ufodf.datetime <= "12/31/2004"), :]
ufo2004.head()
# Out:
#       datetime                         city state country     shape  \
# 138 2004-10-10                       mahwah    nj      us  triangle
# 139 2004-10-10       worthington st. forest    nj     NaN     other
# 140 2004-10-10  portage la prairie (canada)    mb      ca  changing
# 141 2004-10-10                  terre haute    in      us    sphere
# 142 2004-10-10                 indianapolis    in      us      oval
#
#     duration (seconds) duration (hours/min)  \
# 138                180        2 - 3 minutes
# 139               2700               45 min
# 140               1200            20minutes
# 141                  5            5 seconds
# 142                 15           15 seconds
#
#                                               comments date posted  \
# 138  Triangle shaped flying&#44 hovering U.F.O. wit...  12/12/2011
# 139  witnessed a large object and an intense red li...  10/27/2004
# 140  Series of Green Blue Red White lights spherica...  10/27/2004
# 141  silently&#44 it came over my head from behind;...  10/27/2004
# 142  ((NUFORC Note:  Possible sighting of a contrai...  10/27/2004
#
#        latitude  longitude  Unnamed: 11
# 138  41.0886111 -74.144167          nan
# 139   40.058324 -74.405661          nan
# 140   49.966667 -98.300000          nan
# 141  39.4666667 -87.413889          nan
# 142  39.7683333 -86.158056          nan

# %%
# Determine the number of unique UFO reports.
ufo2004.count()
# Out:
# datetime                4711
# city                    4700
# state                   4216
# country                 3992
# shape                   4611
# duration (seconds)      4711
# duration (hours/min)    4535
# comments                4704
# date posted             4711
# latitude                4711
# longitude               4711
# Unnamed: 11               11
# dtype: int64

# %%
# Given the information above, we can use the datetime column to determine the number of unique UFO reports for 2004.
# I will then assign the number of UFO reports to a variable, and then display the variable.
# Note that I will use this technique for all other years.
report2004 = ufo2004.datetime.count()
print(report2004)
# Out:
# 4711

# %%
# Next I'll set up a dataframe of UFO reports in 2005. I'll then check the data.
ufo2005 = ufodf.loc[(ufodf.datetime >= "1/1/2005") & (ufodf.datetime <= "12/31/2005"), :]
ufo2005.head(3)
# Out:
#       datetime               city state country  shape duration (seconds)  \
# 154 2005-10-10            seattle    wa      us  other                 60
# 155 2005-10-10    apache junction    az      us  other                 30
# 156 2005-10-10  north miami beach    fl      us   oval               1800
#
#     duration (hours/min)                                           comments  \
# 154        one + minutes  round symetrical with roundish flat bottom shi...
# 155           30 seconds      half-moon shaped objects that just winked out
# 156           30 minutes  i sent you an e-mail 2 days ago and really wan...
#
#     date posted    latitude   longitude  Unnamed: 11
# 154  10/11/2005  47.6063889 -122.330833          nan
# 155  10/11/2005      33.415 -111.548889          nan
# 156  10/20/2005  25.9327778  -80.162778          nan

# %%
# I'll assign the unique unique number of UFO reports in 2005 to a variable.
report2005 = ufo2005.datetime.count()
print(report2005)
# Out:
# 4478

# %%
# Create a datafram of UFO reports in 2006.
ufo2006 = ufodf.loc[(ufodf.datetime >= "1/1/2006") & (ufodf.datetime <= "12/31/2006"), :]
ufo2006.head(3)
# Out:
#       datetime           city state country     shape duration (seconds)  \
# 167 2006-10-10     pennington    tx      us   diamond               3600
# 168 2006-10-10  san francisco    ca      us  triangle                600
# 169 2006-10-10    blairsville    ga      us   unknown                 10
#
#     duration (hours/min)                                           comments  \
# 167             one hour  IN form of diamond with multi colored lights t...
# 168           10 minutes  black triangles were seen flying across the su...
# 169             <10 sec.  Intermittant streak by moon&#44 not seen on ph...
#
#     date posted    latitude   longitude  Unnamed: 11
# 167    2/1/2007  31.1911111  -95.235278          nan
# 168  10/30/2006      37.775 -122.418333          nan
# 169  10/30/2006  34.8761111  -83.958333          nan

# %%
# Assign the unique number of UFO reports in 2006 to a variable.
report2006 = ufo2006.datetime.count()
print(report2006)
# Out:
# 4121

# %%
# Create a dataframe of UFO reports in 2007
ufo2007 = ufodf.loc[(ufodf.datetime >= "1/1/2007") & (ufodf.datetime <= "12/31/2007"), :]
ufo2007.head(3)
# Out:
#       datetime         city state country     shape duration (seconds)  \
# 179 2007-10-10      lebanon    or      us     light              14400
# 180 2007-10-10  stockbridge    ga      us  changing               3600
# 181 2007-10-10       denver    co      us  changing               2700
#
#     duration (hours/min)                                           comments  \
# 179              4 hours  Small Orange-White &quot;star&quot; that moves...
# 180               1 hour                                     i was abducted
# 181          45 minutes+  Huge lighted cluster in the eastern sky.  ((NU...
#
#     date posted    latitude   longitude  Unnamed: 11
# 179  11/28/2007  44.5366667 -122.905833          nan
# 180  11/28/2007  33.5441667  -84.233889          nan
# 181  11/28/2007  39.7391667 -104.984167          nan

# %%
# Assign the unique number of UFO reports in 2007 to a variable.
report2007 = ufo2007.datetime.count()
print(report2007)
# Out:
# 4688

# %%
# Create a dataframe of UFO reports in 2008
ufo2008 = ufodf.loc[(ufodf.datetime >= "1/1/2008") & (ufodf.datetime <= "12/31/2008"), :]
ufo2008.head(3)
# Out:
#       datetime             city state country   shape duration (seconds)  \
# 200 2008-10-10  london (canada)    on      ca   other                120
# 201 2008-10-10     north branch    mn      us   light                300
# 202 2008-10-10     slingerlands    ny      us  circle                240
#
#     duration (hours/min)                                           comments  \
# 200        2 min. approx  C shape with a T front over London ont on Oct ...
# 201                5 min  Lights at night&#44 shining into car and garag...
# 202                4 min  Huge&#44 moon size&#44 orange&#44 bright&#44 a...
#
#     date posted    latitude  longitude  Unnamed: 11
# 200    6/9/2009   42.983333 -81.250000          nan
# 201  10/31/2008  45.5113889 -92.980000          nan
# 202  10/31/2008  42.6291667 -73.865000          nan

# %%
# Assign the unique number of UFO reports in 2008 to a variable.
report2008 = ufo2008.datetime.count()
print(report2008)
# Out:
# 5247

# %%
# Create a dataframe of UFO reports in 2009
ufo2009 = ufodf.loc[(ufodf.datetime >= "1/1/2009") & (ufodf.datetime <= "12/31/2009"), :]
ufo2009.head(3)
# Out:
#       datetime           city state country      shape duration (seconds)  \
# 219 2009-10-10      greenland   NaN     NaN  rectangle                  0
# 220 2009-10-10  crested butte    co      us        egg                 60
# 221 2009-10-10          tulsa    ok      us    unknown                  6
#
#     duration (hours/min)                                           comments  \
# 219                  NaN  Found this on google maps 70.5&#44 -40.3 Look ...
# 220                 1min  metallic egg shaped craft above crested butte&...
# 221            6 seconds                    In&#39t see nothing in the park
#
#     date posted    latitude   longitude  Unnamed: 11
# 219  12/12/2009           0    0.000000          nan
# 220  12/12/2009  38.8697222 -106.987222          nan
# 221  12/12/2009  36.1538889  -95.992500          nan

# %%
# Assign the unique number of UFO reports in 2009 to a variable
report2009 = ufo2009.datetime.count()
print(report2009)
# Out:
# 4941

# %%
# Create a dataframe of UFO reports in 2010
ufo2010 = ufodf.loc[(ufodf.datetime >= "1/1/2010") & (ufodf.datetime <= "12/31/2010"), :]
ufo2010.head(3)
# Out:
#       datetime          city state country   shape duration (seconds)  \
# 230 2010-10-10  orchard park    ny      us   light               7200
# 231 2010-10-10    harrisburg    pa      us  circle                240
# 232 2010-10-10        euclid    oh      us  circle                180
#
#     duration (hours/min)                                           comments  \
# 230          a few hours  Xmas colored rotating lights.  ((NUFORC Note: ...
# 231           4  minutes                              possible UFO sighting
# 232            3 minutes  2 objects blinking red and white&#44 disappear...
#
#     date posted    latitude  longitude  Unnamed: 11
# 230    1/5/2011     42.7675 -78.744167          nan
# 231  11/21/2010  40.2736111 -76.884722          nan
# 232  11/21/2010  41.5930556 -81.526944          nan

# %%
# Assign the unique number of UFO reports in 2010 to a variable
report2010 = ufo2010.datetime.count()
print(report2010)
# Out:
# 4695

# %%
# Create a dataframe of UFO reports in 2011
ufo2011 = ufodf.loc[(ufodf.datetime >= "1/1/2011") & (ufodf.datetime <= "12/31/2011"), :]
ufo2011.head(3)
# Out:
#       datetime             city state country     shape duration (seconds)  \
# 250 2011-10-10             troy    ny      us  triangle               7200
# 251 2011-10-10       farmington    nm      us    circle                300
# 252 2011-10-10  prescott valley    az      us     other                300
#
#     duration (hours/min)                                           comments  \
# 250              2 hours  Red&#44 green &amp; orange blinking triangle f...
# 251            5 minutes  Single reddish circle  in the sky that wasn&#3...
# 252                hours  Craft boomerang shape.2:00am duration hours.  ...
#
#     date posted    latitude   longitude  Unnamed: 11
# 250  10/10/2011  42.7283333  -73.692222          nan
# 251   8/30/2013  36.7280556 -108.218056          nan
# 252  10/10/2011       34.61 -112.315000          nan

# %%
# Assign the unique number of UFO reports in 2011 to a variable.
report2011 = ufo2011.datetime.count()
print(report2011)
# Out:
# 5530

# %%
# Create a dataframe of UFO reports in 2012.
ufo2012 = ufodf.loc[(ufodf.datetime >= "1/1/2012") & (ufodf.datetime <= "12/31/2012"), :]
ufo2012.head(3)
# Out:
#       datetime                   city state country     shape  \
# 266 2012-10-10             bridgeport    ct      us    circle
# 267 2012-10-10  san francisco airport    ca     NaN  triangle
# 268 2012-10-10              san diego    ca      us    sphere
#
#     duration (seconds) duration (hours/min)  \
# 266                630                10:30
# 267                300            5 minutes
# 268                240            4 minutes
#
#                                               comments date posted  \
# 266                       A Bright light that is a UFO  10/30/2012
# 267  San Francisco International Airport         af...   9/30/2013
# 268  Single white light or craft passed over and ve...  10/30/2012
#
#        latitude   longitude  Unnamed: 11
# 266  41.1669444  -73.205278          nan
# 267   37.615223 -122.389979          nan
# 268  32.7152778 -117.156389          nan

# %%
# Assigning the unique number of UFO reports in 2012 to a variable.
report2012 = ufo2012.datetime.count()
print(report2012)
# Out:
# 7946

# %%
# Create a dataframe of UFO reports in 2013
ufo2013 = ufodf.loc[(ufodf.datetime >= "1/1/2013") & (ufodf.datetime <= "12/31/2013"), :]
ufo2013.head(3)
# Out:
#       datetime         city state country     shape duration (seconds)  \
# 286 2013-10-10      clifton    nj     NaN     light                 60
# 287 2013-10-10  palm harbor    fl      us   chevron                  5
# 288 2013-10-10     sandusky    oh      us  triangle                  0
#
#     duration (hours/min)                                           comments  \
# 286            <1 minute                               Bright light&#33&#33
# 287            5 seconds  Tracking north to south at apx 2500 ft. A very...
# 288            right now  Triangle shaped various different color lights...
#
#     date posted    latitude  longitude  Unnamed: 11
# 286  10/14/2013   40.858433 -74.163755          nan
# 287  10/14/2013  28.0777778 -82.763889          nan
# 288  10/14/2013  41.4488889 -82.708056          nan

# %%
# Assign the Unique number of UFO reports in 2013 to a variable.
report2013 = ufo2013.datetime.count()
print(report2013)
# Out:
# 7608

# %% [markdown]
# # Part 5: Preliminary Analysis of UFO Reports
# ### Sum, Average, Min, Max, and Visualizing the Data

# %%
# Total UFO reports from 2004 to 2013
total = (report2004 + report2005 + report2006 + report2007 + report2008 + report2009 + report2010 + report2011 + report2012 + report2013)
print(total)
# Out:
# 53965

# %%
# Average number of UFO reports.
average = (report2004 + report2005 + report2006 + report2007 + report2008 + report2009 + report2010 + report2011 + report2012 + report2013)/10
print(average)
# Out:
# 5396.5

# %%
# Determine the minimum number of UFO reports in a given year.
report_list = [report2004, report2005, report2006, report2007, report2008, report2009, report2010, report2011, report2012, report2013]
minimum = min(report_list)
print(minimum)
# Out:
# 4121

# %%
# Determine the maximum number of UFO reports in a given year.
maximum = max(report_list)
print(maximum)
# Out:
# 7946

# %%
# Visualizing the frequency of UFO reports between 2004 and 2013.
report_list = [report2004, report2005, report2006, report2007, report2008, report2009, report2010, report2011, report2012, report2013]
years = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
plt.plot(years, report_list)
plt.xlabel("Years")
plt.ylabel("Number of UFO Reports")
plt.title("UFO Reports Between 2004 and 2013")
plt.show()

# %% [markdown]
# # Part 6: The Relationship Between U. S. Military Spending and UFO Reports
# In this section we will (1) determine if there is a correlation between U. S. military spending and the frequency of UFO reports, and (2) create some visualizations of our data.

# %%
# Create a new dataframe with "Years", "U. S. Spending", and "UFO Reports" as column labels. The years will be rows.
# Note that the variables used have already been defined above
df = pd.DataFrame({"Years": years, "U. S. Spending": spending_list, "UFO Reports": report_list})
df
# Out:
#       Years      U. S. Spending  UFO Reports
# 2004   2004 465000000000.000000         4711
# 2005   2005 503000000000.000000         4478
# 2006   2006 528000000000.000000         4121
# 2007   2007 557000000000.000000         4688
# 2008   2008 621000000000.000000         5247
# 2009   2009 669000000000.000000         4941
# 2010   2010 698000000000.000000         4695
# 2011   2011 711000000000.000000         5530
# 2012   2012 685000000000.000000         7946
# 2013   2013 640000000000.000000         7608

# %%
# Perform Pearsons correlation
corr = df["U. S. Spending"].corr(df["UFO Reports"])
corr
# Out:
# 0.4985366146426148

# %%
# Visualizing the correlation with Seaborn
sns.heatmap(df[["U. S. Spending", "UFO Reports"]].corr(), annot = True, vmin = -1, vmax = 1, center = 0)

# %%
# Visualizing data with pairplots
sns.pairplot(df)

# %% [markdown]
# # Part 7: Discussion

# %% [markdown]
# In this project I looked at the amount of U. S. military spending that occurred between 2004 and 2013. I also looked at the number and frequency of UFO reports between 2004 and 2013. It was shown that military spending increased from $465,000,000,000 in 2004 to $640,000,000,000 in 2013. The peak of military spending was $711,000,000,000 in 2011. We also saw an increase in the number of reported UFO sightings between 2004 and 2013. There were 4,711 reports in 2004. And this number rose to 7,608 in 2013. The peak of UFO reports was 7,946 in 2012. Further analysis showed that there was a fairly moderate positive correlation between U. S. military spending and the frequency of UFO reports. While this does not indicate that military spending and ufo reports are causally related, it does show an interesting relationship that can be further explored and analyzed in more detail.
